# %% [markdown]
# # [] Exercise - Building an Agentic RAG System
#
# In this exercise, you will build an Agentic RAG (Retrieval-Augmented Generation) system that
# combines the power of AI agents with traditional RAG pipelines. You'll create an agent that
# can decide when and how to retrieve information from different sources, including vector
# databases, web search, and other tools.

# %% [markdown]
# ## Challenge
#
# Your challenge is to create an Agentic RAG system that can:
#
# - Build a RAG pipeline as a tool that can be used by the agent
# - Create an agent that can decide which tool to use based on the query
# - Handle different types of queries intelligently
# - Combine information from multiple sources when needed

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
from typing import List
from dotenv import load_dotenv

from lib.agents import Agent
from lib.llm import LLM
from lib.state_machine import Run
from lib.messages import BaseMessage
from lib.tooling import tool
from lib.vector_db import VectorStoreManager, CorpusLoaderService
from lib.rag import RAG

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Load data to Vector DB

# %%
db = VectorStoreManager(OPENAI_API_KEY)
db
# Out:
# VectorStoreManager():<chromadb.api.client.Client object at 0x7c8f59cc7620>

# %%
loader_service = CorpusLoaderService(db)

# %%
rag_llm = LLM(
    model="gpt-4o-mini",
    temperature=0.3,
)

# %%
# : Add the games pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method

games_market_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name ="games_market",
        pdf_path = "TheGamingIndustry2024.pdf"
        )
)
# Out:
# VectorStore `games_market` ready!
# Pages from `TheGamingIndustry2024.pdf` added!

# %%
result:Run = games_market_rag.invoke(
    "What's the  state of virtual reality"
)
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# The state of virtual reality (VR) in 2024 is characterized by significant advancements and a growing integration into the gaming industry. VR technology allows gamers to immerse themselves in detailed digital worlds, creating interactive experiences that feel lifelike. Games like "Half-Life: Alyx" exemplify this trend by offering high-fidelity graphics, intuitive controls, and immersive audio, enhancing player engagement. Additionally, VR is being utilized beyond gaming, with applications in education, therapy, and rehabilitation, showcasing its transformative potential in various fields. Overall, VR is evolving as a crucial component of the gaming landscape and is expected to continue shaping how players interact with digital environments.

# %%
# : Add the electric vehicles pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method

electric_vehicles_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name ="ElectricVehicles_market",
        pdf_path = "GlobalEVOutlook2025.pdf"
    )
)
# Out:
# VectorStore `ElectricVehicles_market` ready!
# Pages from `GlobalEVOutlook2025.pdf` added!

# %%
result:Run = electric_vehicles_rag.invoke("What was the number of electric car sales and their market share in Brazil in 2024?")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# In 2024, Brazil had nearly 125,000 electric car sales, which represented a market share of 6.5%.

# %% [markdown]
# ## Tools
#
# In a simple form, Agentic RAG can act like a router, choosing between multiple external sources to retrieve relevant information. These sources aren't limited to databases, they can also include tools like web search or APIs for services such as Slack or email.
#
# In this case it will choose between two collections.

# %%
# : Define a tool that returns result.get_final_state()["answer"]
@tool
def search_global_ev_collection(query):
    result:Run = electric_vehicles_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# : Define a tool that returns result.get_final_state()["answer"]
@tool
def search_games_market_report_collection(query):
    result:Run = electric_vehicles_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# : Add the tools you have defined and the instructions to your agent
agentic_rag = Agent(
    model_name="gpt-4o-mini",
    tools=[search_global_ev_collection, search_games_market_report_collection],    
    instructions= (
        "You are an Agentic RAG assistant that can intelligently decide which tools to use "
        "to answer user questions. Reason about about the response, change the query and call the tool again if needed "
        "in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers."
    )
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages: 
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run

# %%
run_1 = agentic_rag.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
    session_id="oscar",
)

print("\nMessages from run 1:")
messages = run_1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Who won the 2025 Oscar for International Movie?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_FIcCHt7eIQK42XH1aRPczHOk', function=Function(arguments='{"query":"2025 Oscar winner International Movie"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = It seems that the information about the 2025 Oscar winner for International Movie is not available in the current sources. This could be due to the fact that the event has not yet occurred or that the data has not been updated.
#
# If you're interested in previous winners or any other related information, please let me know!, tool_calls = None)

# %%
run_2 = agentic_rag.invoke(
    query= (
        "Which two countries accounted for most of the electric car exports from " 
        "the Asia Pacific region (excluding China) in 2024?"
    ),
    session_id="electric_car",
)

print("\nMessages from run 2:")
messages = run_2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Which two countries accounted for most of the electric car exports from the Asia Pacific region (excluding China) in 2024?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_Ls8IhbPew0BHHqPzP06nzviH', function=Function(arguments='{"query":"electric car exports Asia Pacific region 2024 excluding China"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, Japan and Korea accounted for the majority of the nearly 640,000 electric cars exported from the Asia Pacific region, excluding China, representing an increase of 15% from 2023. The United States was the main destination for these exports, accounting for more than a quarter of the region's production. Europe followed as another significant market, importing another quarter of the region's electric car production.", tool_calls = None)
#  -> (role = assistant, content = In 2024, Japan and Korea were the two countries that accounted for most of the electric car exports from the Asia Pacific region, excluding China. Together, they exported nearly 640,000 electric cars, marking a 15% increase from the previous year., tool_calls = None)

# %%
run_3 = agentic_rag.invoke(
    query= (
        "Why is generative AI seen more as an accelerator than a replacement in game development?"
    ),
    session_id="games",
)

print("\nMessages from run 3:")
messages = run_3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Why is generative AI seen more as an accelerator than a replacement in game development?, tool_calls = None)
#  -> (role = assistant, content = Generative AI is viewed more as an accelerator than a replacement in game development for several reasons:
#
# 1. **Enhancement of Creativity**: Generative AI tools can augment the creative process by providing developers with new ideas, assets, and even narratives. This allows developers to focus on more complex and nuanced aspects of game design while the AI handles repetitive or time-consuming tasks.
#
# 2. **Efficiency in Asset Creation**: AI can automate the creation of assets such as textures, models, and animations, significantly speeding up the development process. This enables teams to deliver games more quickly and efficiently without sacrificing quality.
#
# 3. **Personalization and Adaptability**: Generative AI can help create personalized gaming experiences by adapting content to individual player preferences. This adds a layer of depth and engagement that static content cannot achieve, enhancing the overall player experience.
#
# 4. **Collaboration with Human Developers**: AI serves as a collaborative tool rather than a standalone solution. Developers can leverage AI-generated content while still applying their expertise and vision to ensure that the final product aligns with their creative goals.
#
# 5. **Complex Problem Solving**: Game development often involves solving complex design challenges. Generative AI can assist in this process by providing data-driven insights, modeling scenarios, and suggesting solutions based on vast amounts of data.
#
# 6. **Scalability**: As game worlds become larger and more complex, generative AI can help scale content creation without requiring proportional increases in human resources. This is especially important in open-world and multiplayer games where content needs to be abundant and varied.
#
# In summary, generative AI is seen as an accelerator because it enhances and streamlines the development process, allowing developers to push their creative boundaries while improving efficiency and scalability. It complements human creativity rather than replacing it, making it an invaluable tool in the evolving landscape of game development., tool_calls = None)
